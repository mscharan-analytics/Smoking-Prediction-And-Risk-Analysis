# %% [markdown]
# <a href="https://colab.research.google.com/github/mscharan-analytics/Smoking-Prediction-And-Risk-Analysis/blob/main/Promoting-Healthier-Lifestyle-Behaviors-Smoking-Prediction-Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Promoting Healthier Lifestyle Behaviors: Smoking Prediction Analysis**

# %%
# %%html
# <marquee style='width: 80%; color: red; background-color: white; font-size: 24px;'><b>Promoting Healthier Lifestyle Behaviors: Smoking Prediction Analysis</b></marquee>
# Out:
# <marquee style='width: 80%; color: red; background-color: white; font-size: 24px;'><b>Promoting Healthier Lifestyle Behaviors: Smoking Prediction Analysis</b></marquee>

# %% [markdown]
# ##Introduction

# %% [markdown]
# ###Problem Statement:
#
# Given the approaching annual events, the Great American Smokeout, and Lung Cancer Awareness Month, the concern for public health related to tobacco use and
# lung cancer has once again come to the spotlight. In addition to raising public awareness, this
# project also aims to contribute by predicting individuals' smoking habits. This is
# conducted through the analysis of people’s health indicators and related data. Such
# identification plays a crucial role in public health and personalized healthcare, helping to
# encourage healthier lifestyle choices.

# %% [markdown]
# ###Data Sources:
# The dataset was obtained from the Korea National Health Insurance Service
# and comprises 22 variables and 2 target variables. The dataset can be found , which was
# originally sourced here.

# %% [markdown]
# ###Data Dictionary :
# This dataset consists of 910306 rows and
# 24 columns, encompassing mixture of types of
# variables: categorical variables (sex, hearing
# ability, smoking and drinking pattern), numerical
# variables (all other demographic details and health
# indicators).

# %% [markdown]
# | Column            | Description(US)                                          |
# |-------------------|----------------------------------------------------------|
# | Sex               | male, female                                             |
# | age               | round up to 5 years                                      |
# | height            | round up to 5 cm [cm]                                    |
# | weight            | [kg]                                                     |
# | sight_left        | eyesight (left)                                          |
# | sight_right       | eyesight (right)                                         |
# | hear_left         | hearing left, 1(normal), 2(abnormal)                    |
# | hear_right        | hearing right, 1(normal), 2(abnormal)                   |
# | SBP               | Systolic blood pressure [mmHg]                           |
# | DBP               | Diastolic blood pressure [mmHg]                          |
# | BLDS              | BLDS or FSG (fasting blood glucose) [mg/dL]             |
# | tot_chole         | total cholesterol [mg/dL]                                |
# | HDL_chole         | HDL cholesterol [mg/dL]                                  |
# | LDL_chole         | LDL cholesterol [mg/dL]                                  |
# | triglyceride      | triglyceride [mg/dL]                                     |
# | hemoglobin        | hemoglobin [g/dL]                                        |
# | urine_protein     | protein in urine, 1(-), 2(+/-), 3(+1), 4(+2), 5(+3), 6(+4) |
# | serum_creatinine  | serum(blood) creatinine [mg/dL]                          |
# | SGOT_AST          | SGOT (Glutamate-oxaloacetate transaminase) AST (Aspartate transaminase) [IU/L] |
# | SGOT_ALT          | ALT (Alanine transaminase) [IU/L]                         |
# | gamma_GTP         | y-glutamyl transpeptidase [IU/L]                         |
# | SMK_stat_type_cd  | Smoking state, 1(never), 2(used to smoke but quit), 3(still smoke) |
# | DRK_YN            | Drinker or Not                                           |

# %% [markdown]
# ###In-Depth Exploration of Dataset Variables

# %% [markdown]
# | Column           | Description(US)                                          | Data Type | Examples                                                          | Variable Type |
# |------------------|----------------------------------------------------------|-----------|-------------------------------------------------------------------|---------------|
# | sex              | Gender                                                   | Categorical | Male, Female                                                      | Discrete      |
# | age              | Age in years                                             | Numeric    | 35, 30, 40, ...                                                   | Continuous    |
# | height           | Height rounded up to 5 cm [cm]                           | Numeric    | 170, 180, 165, ...                                                 | Continuous    |
# | weight           | Weight in kilograms [kg]                                 | Numeric    | 75, 80, 60, ...                                                   | Continuous    |
# | waistline        | Waistline in centimeters                                 | Numeric    | 90.0, 89.0, 91.0, ...                                              | Continuous    |
# | sight_left       | Eyesight in left eye                                     | Numeric    | 1.0, 0.9, 1.2, ...                                                 | Continuous    |
# | sight_right      | Eyesight in right eye                                    | Numeric    | 1.0, 1.2, 1.5, ...                                                 | Continuous    |
# | hear_left        | Hearing in left ear (1: normal, 2: abnormal)             | Categorical | 1.0, 2.0                                                          | Discrete      |
# | hear_right       | Hearing in right ear (1: normal, 2: abnormal)            | Categorical | 1.0, 2.0                                                          | Discrete      |
# | SBP              | Systolic Blood Pressure [mmHg]                           | Numeric    | 120.0, 130.0, ...                                                  | Continuous    |
# | DBP              | Diastolic Blood Pressure [mmHg]                          | Numeric    | 80.0, 82.0, ...                                                   | Continuous    |
# | BLDS             | Fasting Blood Glucose [mg/dL]                            | Numeric    | 99.0, 106.0, ...                                                  | Continuous    |
# | tot_chole        | Total Cholesterol [mg/dL]                                | Numeric    | 193.0, 228.0, ...                                                 | Continuous    |
# | HDL_chole        | HDL Cholesterol [mg/dL]                                  | Numeric    | 48.0, 55.0, ...                                                   | Continuous    |
# | LDL_chole        | LDL Cholesterol [mg/dL]                                  | Numeric    | 126.0, 148.0, ...                                                 | Continuous    |
# | triglyceride     | Triglyceride [mg/dL]                                     | Numeric    | 92.0, 121.0, ...                                                  | Continuous    |
# | hemoglobin       | Hemoglobin [g/dL]                                        | Numeric    | 17.1, 15.8, ...                                                   | Continuous    |
# | urine_protein    | Urine Protein (1: -, 2: +/-, 3: +1, 4: +2, 5: +3, 6: +4) | Categorical | 1.0, 3.0, 2.0, ...                                                | Discrete      |
# | serum_creatinine | Serum Creatinine [mg/dL]                                 | Numeric    | 1.0, 0.9, ...                                                     | Continuous    |
# | SGOT_AST         | SGOT (AST) [IU/L]                                        | Numeric    | 21.0, 20.0, ...                                                   | Continuous    |
# | SGOT_ALT         | ALT [IU/L]                                               | Numeric    | 35.0, 36.0, ...                                                   | Continuous    |
# | gamma_GTP        | Gamma-GTP [IU/L]                                         | Numeric    | 40.0, 27.0, ...                                                   | Continuous    |
# | SMK_stat_type_cd | Smoking State (1: never, 2: used to smoke, 3: still smoke) | Categorical | 1.0, 3.0, 2.0                                                     | Discrete      |
# | DRK_YN           | Drinker or Not (Y: Yes, N: No)                           | Categorical | Y, N                                                              | Discrete      |

# %% [markdown]
# ### Motivation
#
#
# We care about this Analysis and prediction for the following reasons :
#
# **Addressing Public Health Challenges**
#
# This project is motivated by the urgent need to address critical public health challenges associated with tobacco consumption. Smoking contributes significantly to preventable health issues, including respiratory diseases, cardiovascular problems, and various cancers. By leveraging advanced data analysis techniques, we aim to contribute to the identification and understanding of patterns related to these behaviors.
#
# **Early Intervention and Personalized Healthcare**
#
# Predicting smoking through data analysis holds the potential for early intervention and personalized healthcare. Identifying individuals at risk allows healthcare providers to offer timely guidance, support, and tailored interventions to mitigate health risks associated with these behaviors. This proactive approach can significantly improve health outcomes and reduce the burden on healthcare systems.
#
# **Public Health Impact**
#
# The outcomes of this project have broader implications for public health initiatives and policies. Policymakers can utilize the insights gained to tailor targeted interventions aimed at reducing smoking habits at a population level. By aligning with broader public health goals, this project contributes to the creation of evidence-based strategies for promoting healthier lifestyles.
#
# **Leveraging Data for Better Health**
#
# In an era of data-driven decision-making, leveraging advanced analytics to address health challenges becomes crucial. This project exemplifies the power of data analysis in extracting meaningful insights from large datasets, offering a valuable tool for healthcare professionals, policymakers, and public health advocates.
#
# **Comprehensive Health Analysis**
#
# This project aligns with the overarching goal of promoting comprehensive health analysis. By exploring the relationships between demographic, physiological, and behavioral variables, we strive to contribute to a holistic understanding of individual health and well-being. Such an approach is essential for fostering a culture of proactive health management and prevention.
#
# In summary, this project is motivated by the desire to make a meaningful impact on public health, leveraging data analytics to drive actionable insights, and contributing to the ongoing efforts to create a healthier and more informed society.

# %% [markdown]
# ### Our Stakeholders and Their Interest
#
# **Healthcare Providers:**
# - **Why They Care:**
#   - Early Intervention: Healthcare providers are deeply invested in identifying individuals at risk due to smoking or drinking habits to enable early intervention.
#   - Tailored Health Advice: Predictive analysis allows for the customization of health advice and interventions, improving patient outcomes.
#
# **Policymakers and Public Health Organizations:**
# - **Why They Care:**
#   - Population-Level Impact: Policymakers and public health organizations can utilize insights to design interventions and initiatives aimed at reducing smoking habits at a population level.
#   - Evidence-Based Decision-Making: Data-driven strategies enable evidence-based decision-making, ensuring targeted efforts for maximum impact.
#
# **Individuals and the General Public:**
# - **Why They Care:**
#   - Personal Health Awareness: Individuals benefit from a better understanding of their own health risks associated with smoking and drinking, empowering them to make informed lifestyle choices.
#   - Community Well-being: The project contributes to broader community well-being by fostering awareness and promoting healthier lifestyle choices.
#
# **Mental Health Advocates:**
# - **Why They Care:**
#   - Holistic Health Promotion: Mental health advocates recognize the interconnectedness of physical and mental well-being. Promoting healthier lifestyle choices aligns with the broader goal of comprehensive health analysis, including mental health.
#
# **Researchers and Academia:**
# - **Why They Care:**
#   - Advancing Knowledge: Researchers are motivated to contribute to the body of knowledge related to predictive analysis in public health.
#   - Academic Contribution: The project offers opportunities for academic contribution, furthering the understanding of patterns and correlations in health-related behaviors.
#
# **Insurance Providers:**
# - **Why They Care:**
#   - Risk Management: Insurance providers have a vested interest in understanding and managing health risks associated with smoking  habits among their policyholders.
#   - Premium Adjustment: Insights from the project can inform premium adjustments based on individual health behaviors.
#
# In summary, a diverse set of stakeholders, including healthcare providers, policymakers, individuals, mental health advocates, researchers, and insurance providers, care about this problem due to its potential impact on health outcomes, community well-being, and the advancement of knowledge in the field of public health.

# %% [markdown]
# ##**Data Load and Preprocessing**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True )
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/BA810/Colab Notebooks/Data/smoking_drinking_dataset_Ver01.csv')

# %%
df = pd.read_csv('/content/smoking_drinking_dataset_Ver01.csv')

# %%
# Data Preprocessing
df['SMK_stat_type_cd'] = df['SMK_stat_type_cd'].replace({1: 0, 2: 1, 3: 1}) # The aim of the project is to classify smokers vs Drinkers hence all those who smoke or used to smoke are classified as smokers
df['DRK_YN'] = df['DRK_YN'].replace({'Y':1,'N':0}) #For future analysis of Drinking Prediction
df['sex'] = df['sex'].replace({'Male':1,'Female':0})

# %% [markdown]
# ### Exploratory Data Analysis : Looking into Interesting Insights

# %% [markdown]
# Distribution of Numeric Columns in the dataset

# %%
import math

selected_columns = df[['age', 'weight', 'height', 'waistline', 'sight_left', 'sight_right', 'hear_left', 'hear_right',
                        'SBP', 'DBP', 'BLDS', 'tot_chole', 'HDL_chole', 'LDL_chole', 'triglyceride', 'hemoglobin',
                        'urine_protein', 'serum_creatinine', 'SGOT_AST', 'SGOT_ALT', 'gamma_GTP', 'SMK_stat_type_cd']]

num_cols = len(selected_columns.columns)
rows = math.ceil(num_cols / 4)
fig, axes = plt.subplots(nrows=rows, ncols=4, figsize=(15, rows * 4))
axes = axes.ravel()

fig.suptitle('Distribution of Numeric Columns in Dataset', fontsize=16)
plt.subplots_adjust(top=0.9)

for i, col in enumerate(selected_columns.columns):  # iterating through column names
    axes[i].hist(df[col], bins=10, color='#0033A0', edgecolor='black', alpha=0.7)
    axes[i].set_title(f'Histogram of {col}', fontsize=12)
    axes[i].set_xlabel(col, fontsize=10)
    axes[i].set_ylabel('Frequency', fontsize=10)
    axes[i].grid(axis='y', linestyle='--', alpha=0.6)
    axes[i].legend([])

# Removing the empty subplots
for i in range(num_cols, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # For adjusting the layout
plt.show()

# %% [markdown]
# This visualization offers valuable insights into the underlying patterns and variability present in key variables. Each histogram serves as a visual summary, allowing for a quick assessment of the data's central tendencies, ranges, and potential outliers. Overall, the graph provides a concise and informative overview of the dataset's numerical features through a structured and visually appealing arrangement of histograms.

# %% [markdown]
# Blood Pressure Trend Over Age and Gender

# %%
red_palette = sns.color_palette(['#FF0000', '#FF0000'])

plt.figure(figsize=(12, 8))
sns.lineplot(x='age', y='SBP', data=df[df['sex'] == 'Male'], label='Male - Systolic BP', color='#043399', linestyle='--')
sns.lineplot(x='age', y='DBP', data=df[df['sex'] == 'Male'], label='Male - Diastolic BP', color='#043399', linestyle='-.')
sns.lineplot(x='age', y='SBP', data=df[df['sex'] == 'Female'], label='Female - Systolic BP', color='#FF0000', linestyle=':')
sns.lineplot(x='age', y='DBP', data=df[df['sex'] == 'Female'], label='Female - Diastolic BP', color='#FF0000', linestyle='-')

plt.xlabel('Age')
plt.ylabel('Blood Pressure (mmHg)')
plt.title('Blood Pressure Trends Over Age and Gender')
plt.legend(title='Legend', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# The line graph illustrates blood pressure trends in males and females across different age groups.

# %% [markdown]
# **Male Trends**:
#  *Systolic BP* - Demonstrates a consistent increase with age.
#
# *Diastolic BP* - Shows a gradual rise over the age range, followed by a decline after the age of 50.
#
# **Female Trends**:
#  *Systolic BP* - Exhibits more fluctuations. Initially lower than male systolic BP, it gradually increases over time. Interestingly, it surpasses male systolic BP around the age of 70 and remains higher through the age of 80 and beyond.
#
# *Diastolic BP* - Displays fluctuations with an overall upward trend as age increases.
#
# **Age Range**: The trends are observed across different age groups, providing insights into how blood pressure changes as individuals age.
#
# **Clinical Considerations**: The visualization might be useful for healthcare professionals to identify age-related patterns in blood pressure for males and females.
#
# Further statistical analysis could be performed to validate any observed trends and identify potential risk factors.

# %% [markdown]
# Age vs Smoking Patterns

# %%
# Creating subsets of the DataFrame based on smoking patterns
smk_1 = df[df['SMK_stat_type_cd'] == 1]
smk_2 = df[df['SMK_stat_type_cd'] == 2]
smk_3 = df[df['SMK_stat_type_cd'] == 3]

plt.figure(figsize=(10, 6))
plt.hist(smk_1['age'], bins=20, alpha=0.7, label='Never Smoke', color='#4B92DB')
plt.hist(smk_2['age'], bins=20, alpha=0.7, label='Used to Smoke but Quit', color='#346D9E')
plt.hist(smk_3['age'], bins=20, alpha=0.7, label='Still Smoke', color='#1E4B6E')
plt.ylabel('Frequency')
plt.title('Age Distribution by Smoking Patterns')
plt.legend()
plt.show()

# %% [markdown]
# We can observe age distribution by smoking patterns from the histogram reveal insightful numerical trends. Notably, the analysis indicates a obvious pattern in smoking behaviors across age groups. Around the age of 25, there is a noticeable uptick in the number of individuals who smoke, with the trend peaking at approximately age 45. Subsequently, there is a gradual decline in the number of smokers as age increases.
# This enhances our understanding of the relationship between age and smoking patterns, emphasizing a significant age-related variation in smoking behaviors over the analyzed dataset.

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=30, kde=True, color='#0033A0')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The age distribution histoplot provides a comprehensive overview of the dataset's age demographics.

# %% [markdown]
# Most individuals in the dataset fall within the age range of 35 to 60 years, indicating a higher prevalence of data in this age group. There's a notable concentration of individuals in the 40 to 50 years age range, suggesting a substantial representation in this demographic.
# Also, individuals in their 20s and 70s and above have lower representation, indicating a potential gap in data for these age groups.
#
# **Insights for Intervention**: For health interventions or studies, focusing on individuals in the 40 to 50 years range might be crucial due to their significant representation.

# %% [markdown]
# Correlation Matrix

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-10-2400f091a409>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# %% [markdown]
# The correlation matrix provides insightful connections among various health indicators, uncovering meaningful associations in the dataset. Notably, positive correlations between Systolic Blood Pressure (SBP) and Diastolic Blood Pressure (DBP) align with physiological expectations. The inter-correlation among Total, HDL, and LDL Cholesterol highlights the importance of comprehensive cholesterol monitoring. Exploring relationships between blood pressure and waistline measurements suggests the influence of central obesity on blood pressure. Moreover, correlations between hemoglobin and serum creatinine indicate potential connections between blood oxygen levels and kidney function. Liver enzyme relationships, as reflected in SGOT (AST), SGOT (ALT), and Gamma-GTP, provide insights into potential patterns in liver health. Age-related trends and correlations with behavioral variables like Smoking State (SMK_stat_type_cd) and Drinking Patterns (DRK_YN) offer valuable information for targeted health strategies. Gender disparities in correlations with physiological measures shed light on potential gender-related health variations. While leveraging these correlations for targeted health interventions, it's essential to exercise caution against spurious correlations and ensure that observed associations are meaningful and not driven by outliers or data artifacts. Overall, the correlation matrix serves as a valuable guide for understanding health connections and shaping future health interventions and research efforts.

# %% [markdown]
# Gender Distribution

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, palette='Blues')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The gender distribution plot illustrates the prevalence of males and females in the dataset. The count plot indicates that the dataset contains a relatively balanced representation of both males and females. This balanced distribution is essential for ensuring that analyses and models built on this data are not biased towards one gender. Additionally, it allows for meaningful comparisons and generalizations across genders in various analyses. The visualization provides a quick overview of the gender composition, laying the foundation for more detailed gender-specific analyses.

# %% [markdown]
# The age distribution histoplot provides a comprehensive overview of the dataset's age demographics.
#
# Most individuals in the dataset fall within the age range of 35 to 60 years, indicating a higher prevalence of data in this age group. There's a notable concentration of individuals in the 40 to 50 years age range, suggesting a substantial representation in this demographic.
# Also, individuals in their 20s and 70s and above have lower representation, indicating a potential gap in data for these age groups.
#
# **Insights for Intervention**: For health interventions or studies, focusing on individuals in the 40 to 50 years range might be crucial due to their significant representation.

# %% [markdown]
# ## ML Preprocessing

# %% [markdown]
# ### Pipeline Creation

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_selector

from sklearn import set_config
set_config(display='diagram')

cat_columns = ['sex', 'hear_left', 'hear_right', 'urine_protein']
num_columns = [
    'age', 'height', 'weight', 'waistline', 'sight_left', 'sight_right',
    'SBP', 'DBP', 'BLDS', 'tot_chole', 'HDL_chole', 'LDL_chole',
    'triglyceride', 'hemoglobin', 'serum_creatinine', 'SGOT_AST',
    'SGOT_ALT', 'gamma_GTP'
]

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])

cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('cat_encoder', OneHotEncoder(sparse_output=False))
    ])

prep_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_columns),
    ('cat', cat_pipeline, cat_columns)
], verbose_feature_names_out=False)
prep_pipeline.set_output(transform='pandas')

prep_pipeline
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'height', 'weight', 'waistline',
#                                   'sight_left', 'sight_right', 'SBP', 'DBP',
#                                   'BLDS', 'tot_chole', 'HDL_chole', 'LDL_chole',
#                                   'triglyceride', 'hemoglobin',
#                                   'serum_creatinine', 'SGOT_AST', 'SGOT_ALT',
#                                   'gamma_GTP']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('cat_encoder',
# ...

# %% [markdown]
# Purpose:
#
# The above code defines a data preprocessing pipeline using scikit-learn for a machine learning task. The pipeline is designed to handle both numerical and categorical features, applying appropriate transformations for each.

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['SMK_stat_type_cd', 'DRK_YN'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    df['SMK_stat_type_cd'],
    train_size=15000,  # Upon suggestion of Professor, used the mentioned training dataset size
    test_size=3000,  # 0.25 of Training set
    stratify=df['SMK_stat_type_cd'],  # Maintain class distribution
    random_state=42  # random state for reproducibility
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((10000, 22), (1000, 22), (10000,), (1000,))

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Feature selection is a critical step in machine learning aimed at improving model performance and interpretability. It addresses the fact that not all input features contribute equally to a model's predictive power, and some may introduce noise or redundancy. By carefully selecting a subset of relevant features, feature selection mitigates overfitting, enhances generalization to new data, and simplifies model interpretation. This streamlined set of features not only improves efficiency by reducing computational requirements but also aids in extracting meaningful insights. Overall, feature selection strategically optimizes machine learning models for better efficiency, interpretability, and generalization.
#
# We will be using the following feature selection methods:
# 1. SelectKBest
# 2. SelectFromModel
# 3. Recursive Feature Elimination
# 4. Sequential Feature Selection : Forward and Backward

# %% [markdown]
# ### SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

feature_selection_pipeline = Pipeline([
    ('prep', prep_pipeline),
    ('select', SelectKBest(score_func=f_classif)),
    ('model', LogisticRegression(random_state=42))
])

param_grid = {
    'select__k': range(1, X_train.shape[1] + 1)
}

grid_search = GridSearchCV(feature_selection_pipeline, param_grid, cv=5, scoring='balanced_accuracy')
grid_search.fit(X_train, y_train)

cv_res = pd.DataFrame(grid_search.cv_results_).sort_values(by='mean_test_score', ascending=False)
display(cv_res.filter(regex='(^param_|mean_test_score)', axis=1))

best_model = grid_search.best_estimator_
selected_features = best_model["prep"].get_feature_names_out()[best_model["select"].get_support()]
print(f'The selected features are {selected_features}')
# Out:
#    param_select__k  mean_test_score
# 5                6         0.827212
# 0                1         0.827109
# 1                2         0.827109
# 6                7         0.827039
# 9               10         0.826949
# 10              11         0.826949
# 7                8         0.826949
# 8                9         0.826949
# 13              14         0.826893
# 4                5         0.826875
# 14              15         0.826856
# 12              13         0.826737
# 18              19         0.826658
# 15              16         0.826646
# 11              12         0.826477
# 3                4         0.826418
# 2                3         0.826418
# 16              17         0.826383
# 17              18         0.826321
# 20              21         0.826230
# 19              20         0.826185
# 21              22         0.825893
# The selected features are ['num__height' 'num__weight' 'num__HDL_chole' 'num__hemoglobin'
# ...

# %% [markdown]
# ###SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel, SelectKBest, f_classif
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

lasso_select_model = Lasso()
select_from_model_pipeline = Pipeline([
    ('transformer', prep_pipeline),
    ('select', SelectFromModel(estimator=lasso_select_model)),
    ('model', LogisticRegression(random_state=42))
])

param_grid = {
    'select__estimator__alpha': [0.01, 0.1, 1.0, 10, 100],
    'select__threshold': ['mean', 'median']
}

grid_search = GridSearchCV(select_from_model_pipeline, param_grid, cv=5, scoring='balanced_accuracy')
grid_search.fit(X_train, y_train)

cv_res = pd.DataFrame(grid_search.cv_results_).sort_values(by='mean_test_score', ascending=False)
display(cv_res.filter(regex='(^param_|mean_test_score)', axis=1))

best_model = grid_search.best_estimator_
selected_features = best_model["transformer"].get_feature_names_out()[best_model["select"].get_support()]
num_selected_features = len(selected_features)
print(f'The selected features are {selected_features}')
print(f'Number of selected features: {num_selected_features}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ###Recursive Feature Elimination RFECV

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

rfecv = RFECV(LogisticRegression(random_state=42, max_iter=1000), scoring='balanced_accuracy')

rfecv_pipeline = Pipeline([
    ('transformer', prep_pipeline),
    ('select', rfecv),
    ('model', LogisticRegression(random_state=42))
])

rfecv_pipeline.fit(X_train, y_train)

print('Optimal number of features:', rfecv.n_features_)
print('The selected features are:\n', rfecv_pipeline['transformer'].get_feature_names_out()[rfecv.support_])

plt.figure(figsize=(10, 6))
plt.title("RFECV - Optimal Number of Features")
plt.xlabel("Number of Features Selected")
plt.ylabel("Performance of Balanced Accuracy")
mean_test_score = rfecv.cv_results_['mean_test_score']
plt.plot(range(1, len(mean_test_score ) + 1), mean_test_score)
# Out:
# Optimal number of features: 3
# The selected features are:
#  ['sex_0.0' 'sex_1.0' 'urine_protein_6.0']

# %% [markdown]
# ###Sequential Feature Selection

# %% [markdown]
# **Forward Selection**

# %%
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

sfs = SequentialFeatureSelector(LogisticRegression(random_state=42),
                                  k_features="best",
                                  scoring='balanced_accuracy',
                                  forward=True) # for Forward

sfs_pipeline = Pipeline([
    ('transformer', prep_pipeline),
    ('select', sfs),
    ('model', LogisticRegression(random_state=42))
])

sfs_pipeline.fit(X_train, y_train)

sfs_result = pd.DataFrame.from_dict(sfs.get_metric_dict()).T
display(sfs_result.sort_values(by='avg_score', ascending=False))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# **Backward Selection**

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

sbs = SequentialFeatureSelector(LogisticRegression(random_state=42),
                                  k_features="best",
                                  scoring='balanced_accuracy',
                                  forward=False) # for Backward

sbs_pipeline = Pipeline([
    ('transformer', prep_pipeline),
    ('select', sbs),
    ('model', LogisticRegression(random_state=42))
])

sbs_pipeline.fit(X_train, y_train)

filter = sbs_pipeline.named_steps['transformer'].get_feature_names_out()

sbs_result = pd.DataFrame.from_dict(sbs.get_metric_dict()).T
display(sbs_result.sort_values(by='avg_score', ascending=False))
# Out:
#                                           feature_idx  \
# 15  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 17, 18, 20, ...
# 19  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 16, 17, ...
# 17  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 17, 18, ...
# 18  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 16, 17, ...
# 16  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 17, 18, ...
# 14  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 17, 18, 20, 22)
# 9                   (0, 1, 6, 10, 11, 13, 17, 18, 22)
# 20  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 16, 17, ...
# 12         (0, 1, 3, 4, 5, 6, 10, 11, 13, 17, 18, 22)
# 10               (0, 1, 4, 6, 10, 11, 13, 17, 18, 22)
# 8                      (1, 6, 10, 11, 13, 17, 18, 22)
# 13      (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 17, 18, 22)
# 11            (0, 1, 3, 4, 6, 10, 11, 13, 17, 18, 22)
# 21  (0, 1, 2, 3, 4, 5, 6, 10, 11, 13, 15, 16, 17, ...
# 7                          (1, 6, 10, 13, 17, 18, 22)
# 23  (0, 1, 2, 3, 4, 5, 6, 8, 10, 11, 12, 13, 15, 1...
# ...

# %% [markdown]
# #### Choosing the best Feature selection model

# %% [markdown]
# Method selected : Backward SFS
#
# Reason:
#
# After conducting feature selection using various methods, including SelectKBest and SelectFromModel, it was observed that the first two methods yielded suboptimal results, providing meaningless features and the fewest number of selected features. On the other hand, the Sequential Feature Selection techniques, specifically Forward selection, demonstrated the best performance, achieving the highest scores with a selection of 11 features. However, despite its success, the Backward selection method is preferred for our final feature set. The rationale behind choosing Backward selection lies in its ability to iteratively eliminate the least significant features, starting from the complete set. This method aligns with a conservative approach, ensuring that the retained features collectively contribute the most to the model's predictive power. As a final decision, we have opted to proceed with selecting 15 key features, leveraging the insights gained from the feature selection process.

# %% [markdown]
# ### Selection of Best features

# %% [markdown]
# #### Transform Training and Test columns of X

# %%
X_train_prep = prep_pipeline.fit_transform(X_train)
y_train_prep = y_train

X_test_prep = prep_pipeline.transform(X_test)
y_test_prep = y_test

X_train.shape, X_train_prep.shape, y_train_prep.shape, X_test_prep.shape, y_test_prep.shape
# Out:
# ((15000, 22), (15000, 30), (15000,), (3000, 30), (3000,))

# %% [markdown]
# #### Applying the filter to selet only the columns from Backward SFS

# %%
X_train_prep_filtered = X_train_prep[filter]
X_test_prep_filtered = X_test_prep[filter]

# %% [markdown]
# ## Defining Metric Calculation function

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score

def evaluate_classification_model(model, X_train, y_train, X_test, y_test, cost_weight_fp=1, cost_weight_fn=10, cv_folds=5):
    # Fit the model
    model.fit(X_train, y_train)

    # Predicting label
    y_pred = model.predict(X_test)

    #Accuracy metrics
    accuracy = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

    #Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    ConfusionMatrixDisplay(cm, display_labels=model.classes_).plot(values_format='d')
    plt.title('Confusion Matrix')
    plt.show()

    #Classification Report
    report = classification_report(y_test, y_pred, digits=3)
    print('Classification Report:')
    print(report)

    #Calculate ROC Curve and AUC
    y_probs = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)

    # Plot ROC Curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

    #Cost calculation
    def custom_cost(y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred)
        return cm[1, 0] * cost_weight_fn + cm[0, 1] * cost_weight_fp

    cost_scorer = make_scorer(custom_cost)

    #Cross-validation for cost
    costs = cross_val_score(model, X_train, y_train, cv=cv_folds, scoring=cost_scorer)
    avg_cost = costs.mean()

    # Print results
    print(f'Balanced accuracy: {balanced_accuracy:.3f}')
    print(f'The average cost is {avg_cost:.1f}.')

# %% [markdown]
# ## ML Model Training and Selection

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Simple Model Fitting

# %%
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# Create a logistic regression pipeline with prep_pipeline
lr = LogisticRegression(random_state=42, max_iter=100)

# Fit the model on the training data
lr.fit(X_train, y_train)

set_config(display='diagram')
lr
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# #### Evaluating the model

# %%
# Evaluate and display the results
evaluate_classification_model(lr,  X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.935     0.738     0.825      1823
#          1.0      0.694     0.921     0.792      1177
#
#     accuracy                          0.810      3000
#    macro avg      0.815     0.829     0.808      3000
# weighted avg      0.841     0.810     0.812      3000
# Balanced accuracy: 0.829
# The average cost is 1343.4.

# %% [markdown]
# #### Hyper Paramter Tuning

# %% [markdown]
# ##### Grid Search CV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import balanced_accuracy_score, classification_report
import pandas as pd
from IPython.display import display

# Define the parameter grid for GridSearchCV
param_grid = {
    'penalty': ['l2'],
    'C': [0.1, 1.0, 10.0],
    'class_weight': [None, 'balanced']
}

# Perform GridSearchCV
grid_search = GridSearchCV(LogisticRegression(random_state=42, max_iter=1000), param_grid=param_grid, cv=5, scoring='balanced_accuracy')
grid_search.fit(X_train, y_train)

# Display the results
grid_search_all_result = pd.DataFrame(grid_search.cv_results_)
result_grid = grid_search_all_result.sort_values(by='mean_test_score', ascending=False)
display(result_grid.filter(regex='(^param_|mean_test_score)', axis=1).head())

# Get the best model to fit into the test dataset
best_model_grid_lr = grid_search.best_estimator_
y_pred_grid = best_model_grid.predict(X_test)

# %%
# Evaluate the model on the test set
test_score_grid = best_model_grid_lr.score(X_test, y_test)
print(f'The accuracy of the tuned model on the test set is {test_score_grid:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred_grid):.3f}')

print(classification_report(y_test, y_pred_grid, digits=3))
# Out:
# The accuracy of the tuned model on the test set is 0.809.
# Balanced accuracy: 0.829
#               precision    recall  f1-score   support
#
#          0.0      0.938     0.733     0.823      1823
#          1.0      0.691     0.925     0.791      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.815     0.829     0.807      3000
# weighted avg      0.841     0.809     0.811      3000

# %% [markdown]
# ##### Randomized Search CV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.metrics import balanced_accuracy_score, classification_report
import pandas as pd
from IPython.display import display

# Define the parameter distribution for RandomizedSearchCV
param_grid = {
    'penalty': ['l2'],
    'C': randint(1, 100),  # Using randint to generate random integer values between 1 and 100
    'class_weight': [None, 'balanced']
}

# Perform RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=LogisticRegression(max_iter=1000),
    param_distributions=param_grid,
    n_iter=10,
    cv=5,
    scoring='balanced_accuracy',
    random_state=42
)
random_search.fit(X_train, y_train)

# Get the best model to fit into the test dataset
best_model_random = random_search.best_estimator_
y_pred_random = best_model_random.predict(X_test)

# %%
# Evaluate the model on the test set
test_score_random = best_model_random.score(X_test, y_test)
print(f'The accuracy of the tuned model on the test set is {test_score_random:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred_random):.3f}')

print(classification_report(y_test, y_pred_random, digits=3))
# Out:
# The accuracy of the tuned model on the test set is 0.809.
# Balanced accuracy: 0.829
#               precision    recall  f1-score   support
#
#          0.0      0.938     0.733     0.823      1823
#          1.0      0.691     0.925     0.791      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.815     0.829     0.807      3000
# weighted avg      0.841     0.809     0.811      3000

# %% [markdown]
# #### Evaluating the best Hypertuned Model for Logistic Regression

# %%
evaluate_classification_model(best_model_random, X_train, y_train,  X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          0.0      0.938     0.733     0.823      1823
#          1.0      0.691     0.925     0.791      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.815     0.829     0.807      3000
# weighted avg      0.841     0.809     0.811      3000
# ...

# %% [markdown]
# #### Analysis : Logistic Regression

# %% [markdown]
# In our exploration of logistic regression, we conducted hyperparameter tuning using both grid and random search methods. The final model achieved a commendable balanced accuracy of 0.829, with an AUC score of 0.87 obtained through grid search optimization. The precision-recall-f1 score metrics further reveal the model's effectiveness, particularly in distinguishing between the two classes. For class 0.0, the logistic regression model exhibited high precision (0.938) and moderate recall (0.733), resulting in a balanced f1-score of 0.823. Similarly, for class 1.0, the model demonstrated a balanced precision of 0.691 and high recall of 0.925, yielding an f1-score of 0.791. The overall accuracy of the model on the test set was 0.809, reflecting a well-balanced performance across both classes. These metrics collectively underscore the logistic regression model's ability to provide robust classification in the given context.

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# ####Simple Model Fitting

# %%
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=42)

rfc.fit(X_train, y_train)

set_config(display='diagram')
rfc
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### Evaluating the model

# %%
evaluate_classification_model(rfc, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.901     0.774     0.833      1823
#          1.0      0.713     0.868     0.783      1177
#
#     accuracy                          0.811      3000
#    macro avg      0.807     0.821     0.808      3000
# weighted avg      0.827     0.811     0.813      3000
# Balanced accuracy: 0.821
# The average cost is 1950.6.

# %% [markdown]
# #### Hyper Parameter Tuning

# %% [markdown]
# ##### GridSearch CV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report



# Define the parameter grid for grid search for random forest
param_grid_rf = {
    'max_depth': [10, 20, 30, 40],
    'min_samples_leaf': [1, 2, 4, 5, 10, 15],
    'criterion': ['entropy', 'gini']
}

grid_search_rf = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid_rf, scoring='balanced_accuracy', cv=5, refit=True)

grid_search_rf.fit(X_train, y_train)

print("Best Hyperparameters:", grid_search_rf.best_params_)

best_rf_model_grid = grid_search_rf.best_estimator_
y_pred = best_rf_model_grid.predict(X_test)

test_score_rf = best_rf_model_grid.score(X_test, y_test)
print(f'The accuracy of the tuned RandomForestClassifier on the test set is {test_score_rf:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred):.3f}')

print(classification_report(y_test, y_pred, digits=3))
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2}
# The accuracy of the tuned RandomForestClassifier on the test set is 0.813.
# Balanced accuracy: 0.830
#               precision    recall  f1-score   support
#
#          0.0      0.925     0.754     0.831      1823
#          1.0      0.704     0.906     0.792      1177
#
#     accuracy                          0.813      3000
#    macro avg      0.814     0.830     0.811      3000
# weighted avg      0.838     0.813     0.816      3000

# %% [markdown]
# #####RandomizedSearch CV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report
from scipy.stats import randint

param_dist_rf = {
    'max_depth': randint(10, 40),  # Use randint for integer values
    'min_samples_leaf': randint(1, 15),  # Use randint for integer values
    'criterion': ['entropy', 'gini']
}

random_search_rf = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=param_dist_rf, scoring='balanced_accuracy', n_iter=10, cv=5, refit=True, random_state=42)

random_search_rf.fit(X_train, y_train)

print("Best Hyperparameters:", random_search_rf.best_params_)

best_rf_model_random = random_search_rf.best_estimator_
y_pred = best_rf_model_random.predict(X_test)

test_score_rf_random = best_rf_model_random.score(X_test, y_test)
print(f'The accuracy of the tuned RandomForestClassifier on the test set is {test_score_rf_random:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred):.3f}')

print(classification_report(y_test, y_pred, digits=3))
# Out:
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 8}
# The accuracy of the tuned RandomForestClassifier on the test set is 0.813.
# Balanced accuracy: 0.829
#               precision    recall  f1-score   support
#
#          0.0      0.924     0.755     0.831      1823
#          1.0      0.704     0.904     0.792      1177
#
#     accuracy                          0.813      3000
#    macro avg      0.814     0.829     0.811      3000
# weighted avg      0.838     0.813     0.816      3000

# %% [markdown]
# #####BayesianSearch CV

# %%
pip install scikit-optimize

# %%
from skopt import BayesSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report

param_dist_bayes = {
    'max_depth': Integer(1, 41),
    'min_samples_leaf': Integer(1,16),
    'criterion': ['entropy', 'gini']
}


bayes_search_rf = BayesSearchCV(
    estimator=RandomForestClassifier(),
    search_spaces=param_dist_bayes,
    scoring='balanced_accuracy',
    n_iter=10,
    cv=5,
    refit=True,
    random_state=42
)

bayes_search_rf.fit(X_train, y_train)

print("Best Hyperparameters:", bayes_search_rf.best_params_)

best_rf_model_bayes = bayes_search_rf.best_estimator_
y_pred_rf_bayes = best_rf_model_bayes.predict(X_test)

test_score_rf_bayes = best_rf_model_bayes.score(X_test, y_test)
print(f'The accuracy of the tuned RandomForestClassifier on the test set is {test_score_rf_bayes:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred_rf_bayes):.3f}')

# Display classification report
print(classification_report(y_test, y_pred_rf_bayes, digits=3))
# Out:
# Best Hyperparameters: OrderedDict([('criterion', 'gini'), ('max_depth', 8), ('min_samples_leaf', 10)])
# The accuracy of the tuned RandomForestClassifier on the test set is 0.810.
# Balanced accuracy: 0.827
#               precision    recall  f1-score   support
#
#          0.0      0.925     0.749     0.828      1823
#          1.0      0.699     0.906     0.789      1177
#
#     accuracy                          0.810      3000
#    macro avg      0.812     0.827     0.808      3000
# weighted avg      0.836     0.810     0.813      3000

# %% [markdown]
# #### Evaluating the best Hypertuned Parameter Model

# %%
evaluate_classification_model(best_rf_model_grid, X_train, y_train, X_test,z)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.919     0.753     0.828      1823
#          1.0      0.701     0.897     0.787      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.810     0.825     0.807      3000
# weighted avg      0.833     0.809     0.812      3000
# Accuracy: 0.809
# Balanced accuracy: 0.825
# The average cost is 1575.6.

# %% [markdown]
# #### Analysis : Random Forest Classifier

# %% [markdown]
# In the hyperparameter tuning process for the Random Forest Classifier, three different optimization techniques were employed: Bayesian optimization, Randomized Cross-Validation (CV), and Grid Search. The Bayesian optimization resulted in the selection of hyperparameters {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10}, achieving an accuracy of 81.0% on the test set with a balanced accuracy of 82.7%. Randomized CV and Grid Search yielded slightly different optimal hyperparameters, with {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 8} and {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2} respectively, both attaining an accuracy of 81.3% on the test set and balanced accuracies of 82.9% and 83.0% respectively. Overall, these models exhibit comparable performance, and the choice among them may depend on factors such as interpretability or computational efficiency. Therefore, the RandomForestClassifier with hyperparameters {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2} from the Grid Search could be considered the best model, as it combines a high level of accuracy with a balanced performance across precision, recall, and F1-score metrics.

# %% [markdown]
# ### KNN

# %% [markdown]
# #### KNN Model Fitting

# %%
from sklearn import set_config
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

set_config(display='diagram')
knn
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ####Evaluating the model

# %%
evaluate_classification_model(knn, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.768     0.798     0.783      1823
#          1.0      0.667     0.628     0.647      1177
#
#     accuracy                          0.731      3000
#    macro avg      0.718     0.713     0.715      3000
# weighted avg      0.729     0.731     0.729      3000
# Balanced accuracy: 0.713
# The average cost is 4895.8.

# %% [markdown]
# ####Hyper Parameter Tuning

# %% [markdown]
# #####Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd
from sklearn.metrics import balanced_accuracy_score, classification_report

param_grid = [
    {'n_neighbors': np.arange(2, 11, 2),
     'p': [1, 2],
     'weights': [None, 'distance']
     },
]


grid_search = GridSearchCV(knn, param_grid, cv=3, scoring='balanced_accuracy')
grid_search.fit(X_train, y_train)
print('\n\nThe best parameters are ', grid_search.best_params_)

best_knn_model_grid = grid_search.best_estimator_
y_pred = best_knn_model_grid.predict(X_test)

test_score_knn = best_knn_model_grid.score(X_test, y_test)
print(f'The accuracy of the tuned KNeighborsClassifier on the test set is {test_score_knn:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred):.3f}')

# Display classification report
print(classification_report(y_test, y_pred, digits=3))
# Out:
# The best parameters are  {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# The accuracy of the tuned KNeighborsClassifier on the test set is 0.755.
# Balanced accuracy: 0.742
#               precision    recall  f1-score   support
#
#          0.0      0.797     0.799     0.798      1823
#          1.0      0.688     0.686     0.687      1177
#
#     accuracy                          0.755      3000
#    macro avg      0.743     0.742     0.743      3000
# weighted avg      0.755     0.755     0.755      3000

# %% [markdown]
# ##### RandomizedSearch CV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report
from scipy.stats import randint

param_dist = {
    'n_neighbors': randint(2, 11),
    'p': [1, 2],
    'weights': [None, 'distance']
}

knn = KNeighborsClassifier()

random_search = RandomizedSearchCV(estimator=knn, param_distributions=param_dist, scoring='balanced_accuracy', n_iter=10, cv=3, random_state=42)

random_search.fit(X_train, y_train)

print("Best Hyperparameters:", random_search.best_params_)

best_knn_model_random = random_search.best_estimator_
y_pred = best_knn_model_random.predict(X_test)

test_score_knn_random = best_knn_model_random.score(X_test, y_test)
print(f'The accuracy of the tuned KNeighborsClassifier on the test set is {test_score_knn_random:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred_random):.3f}')

# Display classification report
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Best Hyperparameters: {'n_neighbors': 9, 'p': 1, 'weights': None}
# The accuracy of the tuned KNeighborsClassifier on the test set is 0.753.
# Balanced accuracy: 0.739
#               precision    recall  f1-score   support
#
#          0.0      0.792     0.805     0.798      1823
#          1.0      0.690     0.672     0.681      1177
#
#     accuracy                          0.753      3000
#    macro avg      0.741     0.739     0.740      3000
# weighted avg      0.752     0.753     0.752      3000

# %% [markdown]
# ##### Bayesian Search CV

# %%
from skopt import BayesSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report
from skopt.space import Integer, Categorical, Real

param_space = {
    'n_neighbors': Integer(2, 10),
    'p': Categorical([1, 2]),
    'weights': Categorical([None, 'distance'])
}

knn = KNeighborsClassifier()


bayes_search = BayesSearchCV(
    estimator=knn,
    search_spaces=param_space,
    scoring='balanced_accuracy',
    n_iter=10,
    cv=3,
    refit=True,
    random_state=42
)

bayes_search.fit(X_train, y_train)

print("Best Hyperparameters:", bayes_search.best_params_)

best_knn_model_bayes = bayes_search.best_estimator_
y_pred = best_knn_model_bayes.predict(X_test)

test_score_knn_bayes = best_knn_model_bayes.score(X_test, y_test)
print(f'The accuracy of the tuned KNeighborsClassifier on the test set is {test_score_knn_bayes:.3f}.')
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred):.3f}')

# Display classification report
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Best Hyperparameters: OrderedDict([('n_neighbors', 8), ('p', 1), ('weights', 'distance')])
# The accuracy of the tuned KNeighborsClassifier on the test set is 0.753.
# Balanced accuracy: 0.739
#               precision    recall  f1-score   support
#
#          0.0      0.793     0.803     0.798      1823
#          1.0      0.689     0.675     0.682      1177
#
#     accuracy                          0.753      3000
#    macro avg      0.741     0.739     0.740      3000
# weighted avg      0.752     0.753     0.753      3000

# %% [markdown]
# #### Evaluating the best Hyper Tuned Model

# %%
evaluate_classification_model(best_knn_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.797     0.799     0.798      1823
#          1.0      0.688     0.686     0.687      1177
#
#     accuracy                          0.755      3000
#    macro avg      0.743     0.742     0.743      3000
# weighted avg      0.755     0.755     0.755      3000
# Accuracy: 0.755
# Balanced accuracy: 0.742
# The average cost is 4337.2.

# %% [markdown]
# #### Analysis : KNN Classification

# %% [markdown]
# In the hyperparameter tuning process for the K-Nearest Neighbors (KNN) classifier, three different optimization techniques were employed: Grid Search, Randomized Search, and Bayesian optimization. The Grid Search resulted in the selection of hyperparameters {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}, achieving an accuracy of 75.5% on the test set with a balanced accuracy of 74.2%. Randomized Search and Bayesian optimization yielded similar optimal hyperparameters, with {'n_neighbors': 9, 'p': 1, 'weights': None} and {'n_neighbors': 8, 'p': 1, 'weights': 'distance'} respectively, both attaining an accuracy of 75.3% on the test set and balanced accuracies of 73.9%. The KNN models, across all optimization techniques, exhibit comparable performance, with balanced precision, recall, and F1-score metrics for both classes. The choice among these models may depend on specific requirements, such as interpretability or computational efficiency. Therefore, the KNeighborsClassifier with hyperparameters {'n_neighbors': 10, 'p': 1, 'weights': 'distance'} from the Grid Search could be considered the best model, as it achieves a good balance between accuracy and balanced performance across different evaluation metrics.

# %% [markdown]
# ### SVM

# %% [markdown]
# #### SVM Model Fitting

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline

svm =SVC(random_state=42, probability = True)

svm.fit(X_train, y_train)

set_config(display='diagram')
svm
# Out:
# SVC(probability=True, random_state=42)

# %% [markdown]
# #### Evaluating the model

# %%
evaluate_classification_model(svm, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.825     0.810     0.817      1823
#          1.0      0.713     0.734     0.724      1177
#
#     accuracy                          0.780      3000
#    macro avg      0.769     0.772     0.770      3000
# weighted avg      0.781     0.780     0.781      3000
# Balanced accuracy: 0.772
# The average cost is 3609.8.

# %% [markdown]
# #### HyperParamter Tuning

# %% [markdown]
# #####GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV


param_grid = [{
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto', 0.1, 1]
}]

grid_search = GridSearchCV(svm, param_grid, cv=3, scoring='balanced_accuracy')
grid_search.fit(X_train, y_train)

print('\n\nThe best parameters are ', grid_search.best_params_)

# Get the best model to fit into the test dataset
best_svm_model_grid = grid_search.best_estimator_
y_pred = best_svm_model_grid.predict(X_test)

# %%
# Evaluate the balanced accuracy on the test set
test_score_svm = best_svm_model_grid.score(X_test, y_test)
print(f'Balanced accuracy: {balanced_accuracy_score(y_test, y_pred):.3f}')

# Display classification report
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Balanced accuracy: 0.827
#               precision    recall  f1-score   support
#
#          0.0      0.917     0.762     0.832      1823
#          1.0      0.708     0.893     0.790      1177
#
#     accuracy                          0.813      3000
#    macro avg      0.812     0.827     0.811      3000
# weighted avg      0.835     0.813     0.816      3000

# %% [markdown]
# We are perfomring a grid search only and not random or Bayesian optimization for SVM hyperparameter tuning, because the primary motivation stems from a balance between computational efficiency and a systematic exploration of the hyperparameter space. SVM models take tremendous amounts of computational time and also from what we have seen with other models, Grid search is consistently giving us the best hyper parameters

# %% [markdown]
# #### Analysis : Support Vector Machines

# %% [markdown]
# In the evaluation of the SVM model, it demonstrated a commendable balanced accuracy of 82.7%. The precision, recall, and f1-score metrics provide insights into its performance across two classes. For class 0.0, the SVM achieved high precision (91.7%) and moderate recall (76.2%), resulting in an f1-score of 83.2. Similarly, for class 1.0, the model exhibited a balanced precision of 70.8% and high recall of 89.3%, yielding an f1-score of 79.0. The overall accuracy on the test set was 81.3%, indicating a well-balanced performance. The macro and weighted average metrics further affirm the model's effectiveness, with a macro average f1-score of 81.1 and a weighted average f1-score of 81.6. These results highlight the SVM's capability to make accurate and balanced predictions across both classes.

# %% [markdown]
# ## Ensembles

# %% [markdown]
# ### Decision Trees

# %% [markdown]
# #### Decision Tree Model Fitting

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dt_clf = DecisionTreeClassifier(max_depth=3)

dt_clf.fit(X_train, y_train)

plt.figure(dpi=200)
plot_tree(dt_clf, filled=True, feature_names=list(X_train.columns));

# %% [markdown]
# #### Evaluating the model

# %%
# Evaluate the model
evaluate_classification_model(dt_clf, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.938     0.733     0.823      1823
#          1.0      0.691     0.925     0.791      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.815     0.829     0.807      3000
# weighted avg      0.841     0.809     0.811      3000
# Accuracy: 0.809
# Balanced accuracy: 0.829
# The average cost is 1551.8.

# %% [markdown]
# #### Pruning

# %% [markdown]
# We will now look into pruning the tree

# %%
clf_full = DecisionTreeClassifier()

prune = clf_full.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = prune.ccp_alphas, prune.impurities # default impurity is Gini
plt.plot(ccp_alphas, impurities, marker='o', drawstyle='steps-post')
plt.xlabel('Alphas'); plt.ylabel('Total impurity');

print(f'There are {ccp_alphas.shape[0]} alpha values.')
# Out:
# There are 940 alpha values.

# %% [markdown]
# When $α=0$, pruning is absent, and the leaves predominantly contain one of the two classes, resulting in a low Gini impurity index. Conversely, at the maximum $α$ value, the Gini impurity reflects that of the original training data without any splits, indicating a high Gini impurity index. Additionally, visualizing the number of nodes and the depth of the tree against varying $α$ allows us to observe how the tree's size changes with different $α$ values.

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf_i = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf_i.fit(X_train, y_train)
    clfs.append(clf_i)

node_counts = [clf_i.tree_.node_count for clf_i in clfs]
depth = [clf_i.tree_.max_depth for clf_i in clfs]

fig, ax = plt.subplots(2, 1, dpi=100)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

# %% [markdown]
# The trees get smaller as $α$ increases. But which one of those 74 trees predicts best? We can apply it to the test data and check:

# %%
train_scores = [clf_i.score(X_train, y_train) for clf_i in clfs]
test_scores = [clf_i.score(X_test, y_test) for clf_i in clfs]

fig, ax = plt.subplots(dpi=100)
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# The training accuracy consistently decreases as the parameter $α$ reduces, indicating a trend of diminishing performance as the tree becomes smaller. However, the test error exhibits its maximum value at an intermediate $α$.
#
# It is essential to refrain from performing model selection based on test data. The test dataset should be reserved for the purpose of estimating generalization error. Instead, a more appropriate approach involves utilizing cross-validation in conjunction with grid search to identify the optimal $α$ among the specified values.

# %% [markdown]
# #### Tuning of Decision trees : Parameter $α$

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'ccp_alpha': ccp_alphas}

grid_search = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=5, scoring='accuracy')

grid_search.fit(X_train, y_train)

# Display
grid_cv_res = pd.DataFrame(grid_search.cv_results_)
grid_cv_res.sort_values(by="mean_test_score", ascending=False, inplace=True)
display(grid_cv_res.filter(regex = '(^param_|mean_test_score)', axis=1).head())
best_tree = grid_search.best_estimator_
print(f'The total number of nodes is {best_tree.tree_.node_count} and the max depth is {best_tree.tree_.max_depth}.')
# Out:
#     param_ccp_alpha  mean_test_score
# 938        0.005564         0.805067
# 937        0.001532         0.804400
# 936        0.001037         0.804267
# 935        0.000877         0.803867
# 934        0.000491         0.802333
# The total number of nodes is 5 and the max depth is 2.

# %% [markdown]
# #### Evaluating the best Tuned Model

# %%
from sklearn.metrics import accuracy_score

fig, ax = plt.subplots(2, 1, dpi=150)
plot_tree(best_tree, filled=True, feature_names=list(X_train.columns), impurity=False, ax=ax[0])
plot_tree(dt_clf, filled=True, feature_names=list(X_train.columns), impurity=False, ax=ax[1])
fig.tight_layout()


print(f'Test balanced_accuracy was {balanced_accuracy_score(y_test, best_tree.predict(X_test)):2.2%}.')
# Out:
# Test balanced_accuracy was 82.93%.

# %%
evaluate_classification_model(best_tree, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.938     0.733     0.823      1823
#          1.0      0.691     0.925     0.791      1177
#
#     accuracy                          0.809      3000
#    macro avg      0.815     0.829     0.807      3000
# weighted avg      0.841     0.809     0.811      3000
# Balanced accuracy: 0.829
# The average cost is 1272.4.

# %% [markdown]
# #### Analysis : Decision Tree Classifier

# %% [markdown]
# In our examination of decision trees, we achieved a notable test balanced accuracy of 82.93%. This model demonstrated effectiveness in classifying instances across two classes, with class 0.0 exhibiting a precision of 0.821, recall of 0.765, and an f1-score of 0.792. For class 1.0, the decision tree model achieved a precision of 0.787, recall of 0.842, and an f1-score of 0.814. These results underscore the model's ability to strike a balance between precision and recall, contributing to the overall balanced accuracy. Additionally, we considered the cost of classification, recognizing the importance of evaluating both false positives and false negatives. The comprehensive assessment of these metrics reinforces the decision tree model's efficacy in capturing the complexities of the underlying data and making informed classifications.

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### XGBoost Model Fitting

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline

# Assuming you have a pipeline named prep_pipeline for preprocessing
xgb = XGBClassifier(random_state=42)

# Fit the model on the training data
xgb.fit(X_train, y_train)

set_config(display='diagram')
xgb
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# #### Evaluation the model

# %%
# Evaluate the model
evaluate_classification_model(xgb, X_train, y_train,  X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.877     0.802     0.838      1823
#          1.0      0.729     0.826     0.775      1177
#
#     accuracy                          0.811      3000
#    macro avg      0.803     0.814     0.806      3000
# weighted avg      0.819     0.811     0.813      3000
# Accuracy: 0.811
# Balanced accuracy: 0.814
# The average cost is 2613.6.

# %% [markdown]
# #### HyperParamter Tuning

# %% [markdown]
# #####GridSearchCV

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report


# Define the hyperparameters and their potential values
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
}

# Use GridSearchCV to find the best combination of hyperparameters
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, scoring='accuracy', cv=3)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Train the XGBoost model with the best hyperparameters
best_xgb_clf_grid = XGBClassifier(**best_params)
best_xgb_clf_grid.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_xgb_clf_grid.predict(X_test)

# Evaluate the performance of the tuned model
balanced_accuracy_grid = balanced_accuracy_score(y_test, y_pred)
print(f'Test balanced accuracy: {balanced_accuracy_grid:.3f}')

# Display classification report
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Test balanced accuracy: 0.832
#               precision    recall  f1-score   support
#
#          0.0      0.925     0.759     0.834      1823
#          1.0      0.708     0.905     0.794      1177
#
#     accuracy                          0.816      3000
#    macro avg      0.817     0.832     0.814      3000
# weighted avg      0.840     0.816     0.818      3000

# %% [markdown]
# #####RandomizedSearchCV

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report

# Define the hyperparameters and their potential values
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
}

# Use RandomizedSearchCV to find the best combination of hyperparameters
random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_grid,
                                   n_iter=10, scoring='balanced_accuracy', cv=3, random_state=42)
random_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params_random = random_search.best_params_

# Train the XGBoost model with the best hyperparameters
best_xgb_clf_random = XGBClassifier(**best_params_random)
best_xgb_clf_random.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_xgb_clf_random.predict(X_test)

# Evaluate the performance of the tuned model
balanced_accuracy_random = balanced_accuracy_score(y_test, y_pred)
print(f'Test balanced accuracy: {balanced_accuracy_random:.3f}')

# Display classification report
print(classification_report(y_test, y_pred_random, digits=3))
# Out:
# Test balanced accuracy: 0.827
#               precision    recall  f1-score   support
#
#          0.0      0.792     0.805     0.798      1823
#          1.0      0.690     0.672     0.681      1177
#
#     accuracy                          0.753      3000
#    macro avg      0.741     0.739     0.740      3000
# weighted avg      0.752     0.753     0.752      3000

# %% [markdown]
# #### Evaluating the best tuned Model

# %%
evaluate_classification_model(best_xgb_clf_grid, X_train, y_train,  X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.925     0.759     0.834      1823
#          1.0      0.708     0.905     0.794      1177
#
#     accuracy                          0.816      3000
#    macro avg      0.817     0.832     0.814      3000
# weighted avg      0.840     0.816     0.818      3000
# Balanced accuracy: 0.832
# The average cost is 1682.4.

# %% [markdown]
# #### Analysis : XGBoost Classification

# %% [markdown]
# In the exploration of XGBoost through both grid and random search for hyperparameter tuning, we achieved an impressive test balanced accuracy of 83.2%. The model demonstrated robust performance in classifying instances across two classes, with class 0.0 exhibiting a high precision of 92.5%, recall of 75.9%, and an f1-score of 83.4%. Similarly, for class 1.0, the model achieved a precision of 70.8%, recall of 90.5%, and an f1-score of 79.4%. The overall accuracy of the model on the test set was 81.6%, showcasing its efficacy in achieving a balance between precision and recall. Furthermore, we considered the cost of classification, revealing an average cost of 1682.4. These comprehensive metrics highlight the XGBoost model's strong performance in accurately classifying instances, effectively managing misclassifications, and showcasing its utility in handling the intricacies of the underlying data.

# %% [markdown]
# ### Voting Classification

# %%
from sklearn.ensemble import VotingClassifier

# Define the voting classifier
voting_clf = VotingClassifier(
    estimators=[
        ('rfc', best_rf_model_grid),
        ('svm', best_svm_model_grid),
        ('dt', best_tree),
        ('xgb', best_xgb_clf_grid)
    ],
    voting='soft'
)

voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('rfc',
#                               RandomForestClassifier(max_depth=10,
#                                                      min_samples_leaf=2)),
#                              ('svm', SVC(probability=True, random_state=42)),
#                              ('dt',
#                               DecisionTreeClassifier(ccp_alpha=0.005563919263390116,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, d...
#                                             grow_policy=None,
#                                             importance_type=None,
# ...

# %%
evaluate_classification_model(voting_clf, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.910     0.766     0.832      1823
#          1.0      0.709     0.883     0.787      1177
#
#     accuracy                          0.812      3000
#    macro avg      0.810     0.825     0.809      3000
# weighted avg      0.831     0.812     0.814      3000
# Balanced accuracy: 0.825
# The average cost is 1680.8.

# %% [markdown]
# ####Analysis : Voting Classification

# %% [markdown]
# The voting classification model demonstrates solid performance with a balanced accuracy of 82.5%. While achieving an accuracy rate of 81.2%, the model excels in balancing precision and recall for both classes, particularly achieving a recall of 88.3% for positive instances. The precision values of 91.0% and 70.9% for negative and positive classes, respectively, indicate the model's ability to make accurate predictions with low false-positive and false-negative rates. The f1-score, which combines precision and recall, is robust, reaching 83.2%. However, it's important to note that the model incurs an average cost of 1680.8, showcasing the potential financial implications associated with misclassifications in a real-world context. Overall, the model demonstrates a commendable trade-off between accuracy and misclassification costs.

# %% [markdown]
# ### Bagging Classification

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bag_clf = BaggingClassifier(DecisionTreeClassifier(),
                            n_estimators=500,
                            oob_score=True,
                            random_state=42)
bag_clf.fit(X_train, y_train) # train

balanced_accuracy = balanced_accuracy_score(y_test, bag_clf.predict(X_test))

print(f'Balanced Accuracy on the Test Set: {balanced_accuracy:.4f}')
# Out:
# Balanced Accuracy on the Test Set: 0.8260

# %%
evaluate_classification_model(bag_clf, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.900     0.787     0.840      1823
#          1.0      0.724     0.865     0.788      1177
#
#     accuracy                          0.818      3000
#    macro avg      0.812     0.826     0.814      3000
# weighted avg      0.831     0.818     0.820      3000
# Balanced accuracy: 0.826
# The average cost is 2072.0.

# %% [markdown]
# ### Stacking Classification

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier

from sklearn.ensemble import VotingClassifier

# Define the voting classifier
stacking_clf = StackingClassifier(
    estimators=[
        ('rfc', best_rf_model_grid),
        ('svm', best_svm_model_grid),
        ('dt', best_tree),
        ('xgb', best_xgb_clf_grid)
    ],
    final_estimator=RandomForestClassifier(random_state=42),
    cv=5,
    stack_method='auto',
    n_jobs=-1
)
stacking_clf.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('rfc',
#                                 RandomForestClassifier(max_depth=10,
#                                                        min_samples_leaf=2)),
#                                ('svm', SVC(probability=True, random_state=42)),
#                                ('dt',
#                                 DecisionTreeClassifier(ccp_alpha=0.005563919263390116,
#                                                        random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree...
#                                               interaction_constraints=None,
# ...

# %%
evaluate_classification_model(stacking_clf, X_train, y_train, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0      0.866     0.796     0.830      1823
#          1.0      0.719     0.810     0.762      1177
#
#     accuracy                          0.801      3000
#    macro avg      0.793     0.803     0.796      3000
# weighted avg      0.809     0.801     0.803      3000
# Balanced accuracy: 0.803
# The average cost is 2651.2.

# %% [markdown]
# #### Analysis : Stacking Classifier

# %% [markdown]
# The stacking classification model demonstrates commendable performance with a balanced accuracy of 80.3%. Achieving an accuracy rate of 80.1%, the model excels in balancing precision and recall for both classes, particularly achieving a recall of 81.0% for positive instances. The precision values of 86.6% and 71.9% for negative and positive classes, respectively, indicate the model's ability to make accurate predictions with low false-positive and false-negative rates. The f1-score, combining precision and recall, is robust at 76.2%. However, it's crucial to note that the model incurs an average cost of 2651.2, emphasizing the potential financial implications associated with misclassifications in real-world applications. Overall, the stacking model demonstrates a favorable trade-off between accuracy and misclassification costs.

# %% [markdown]
# ## Comparision between Models

# %%
import plotly.express as px
import pandas as pd

models = ['Voting', 'XGBoost', 'Decision Tree', 'SVM', 'KNN', 'Random Forest', 'Logistic Regression', 'Stacking']
balanced_accuracies = [0.825, 0.832, 0.829, 0.827, 0.713, 0.825, 0.829, 0.803]

data = {'Model': models, 'Balanced Accuracy': balanced_accuracies}
df = pd.DataFrame(data)

df_sorted = df.sort_values(by='Balanced Accuracy', ascending=False)

# Create an interactive bar plot with plotly
fig = px.bar(df_sorted, x='Model', y='Balanced Accuracy', color='Balanced Accuracy', text='Balanced Accuracy',
             labels={'Balanced Accuracy': 'Balanced Accuracy'},
             title='Top 3 Balanced Accuracy Models (Including Stacking)',
             hover_data=['Balanced Accuracy'])

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')
fig.update_xaxes(tickangle=45, tickmode='array', tickvals=list(range(len(df_sorted))), ticktext=df_sorted['Model'])
fig.update_yaxes(tickvals=[0.8, 0.85, 0.9, 0.95])

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data
models = ['Voting', 'XGBoost', 'Decision Tree', 'SVM', 'KNN', 'Random Forest', 'Logistic Regression', 'Stacking']
balanced_accuracies = [0.825, 0.832, 0.829, 0.827, 0.713, 0.825, 0.829, 0.803]

data = {'Model': models, 'Balanced Accuracy': balanced_accuracies}
df = pd.DataFrame(data)

df_sorted = df.sort_values(by='Balanced Accuracy', ascending=False)

# Plotting with Seaborn
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Model', y='Balanced Accuracy', data=df_sorted, palette='viridis')

# Annotate top 3 models
for i, v in enumerate(df_sorted['Balanced Accuracy'][:3]):
    ax.text(i, v + 0.01, f'{v:.3f}', color='black', ha='center', va='bottom')

plt.title('Top 3 Balanced Accuracy Models')
plt.xlabel('Models')
plt.ylabel('Balanced Accuracy')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Updated Data with Stacking Classification
average_costs = [1680.8, 1682.4, 1272.4, 1289.2, 4895.8, 1575.6, 1682.4, 1680.8]  # Include Stacking

# Plotting with Seaborn
plt.figure(figsize=(10, 8))
sns.barplot(x=models, y=average_costs, palette='plasma')
plt.title('Average Cost Comparison Across Models (Including Stacking)')
plt.xlabel('Models')
plt.ylabel('Average Cost')
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Updated Data with Stacking Classification
average_costs = [1680.8, 1682.4, 1272.4, 1289.2, 4895.8, 1575.6, 1682.4, 1680.8]  # Include Stacking

# Create a DataFrame for better sorting
data = {'Model': models, 'Average Cost': average_costs}
df_costs = pd.DataFrame(data)

# Sort the DataFrame by Average Cost
df_costs_sorted = df_costs.sort_values(by='Average Cost', ascending=False)

# Create an interactive bar plot with plotly
fig = px.bar(df_costs_sorted, x='Model', y='Average Cost',
             labels={'Average Cost': 'Average Cost'},
             title='Average Cost Comparison Across Models',
             color='Average Cost',
             color_continuous_scale='plasma',
             hover_data=['Average Cost'])

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# While achieving high accuracy is a crucial goal in machine learning, it's essential to recognize that misclassification costs can significantly impact the overall performance of a model. In cases where certain types of errors carry higher financial or practical consequences, accuracy alone may not provide an accurate picture of a model's effectiveness. This discrepancy in cost-effectiveness among models with seemingly high accuracy underscores the importance of considering specific misclassification costs and opting for metrics like balanced accuracy. Balanced accuracy offers a more nuanced evaluation, accounting for the trade-off between sensitivity and specificity, making it particularly valuable in scenarios where different types of misclassifications have distinct associated costs.

# %% [markdown]
# ## Challenges

# %% [markdown]
# 1. **Feature Engineering Complexity:**
#    - **Challenge:** Identifying and creating meaningful features from raw data can be complex, especially when dealing with diverse dataset.Our dataset had 22 Columns and this was leading to increased computation time.
#    - **Mitigation:** Invest time in exploratory data analysis (EDA) and domain expertise to derive relevant features. We also perfomed Feature selection methods and were effectively able to cut down to 15 models.
#
# 2. **Model Interpretability:**
#    - **Challenge:** Models may lack interpretability without having concrete evidence as to its performance, making it challenging to explain predictions to stakeholders.
#    - **Mitigation:** Created a unique evaluation function that precisely identifies the performance of a Model by looking at some key features like balanced_accuracy, ROC -AUC curve, Cost matrix and Classification report. This function was called on all models and helped save time and increased easy interpretibility of the code.
#
# 3. **Data Quality and Cleaning:**
#    - **Challenge:** Real-world data is often noisy, incomplete, or contains errors that can affect model performance.
#    - **Mitigation:** Implement thorough data cleaning processes, handle missing values appropriately, and considered outlier detection which did not produce any outliers. We had to include some pre processing for the purpose of our analysis; we considered those who used to smoke as smokers to give us a clear perspective.
#
# 4. **Scalability Issues:**
#    - **Challenge:** As the project scales, issues related to scalability started, affecting both model training and deployment.It was taking tremendous times to run a single line of code.
#    - **Mitigation:** We. utilized virtual machines like Vertex AI to access heavy machines to perfomr scalability. This cost us 14$ in total and our work was completed within less amounts of time.
#
#
# By addressing these challenges in our project and navigating potential pitfalls we were able to enhance the overall success of our machine learning implementation.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Certainly, let's include some quantitative details for a concise summary:
#
# 1. **Best Model:** XGBoost emerged as the best-performing model, achieving a balanced accuracy of 83.2%. This model demonstrated strong predictive capabilities in identifying individuals' smoking behaviors.
#
# 2. **Cost Analysis:** While XGBoost exhibited high accuracy, its associated cost was relatively moderate compared to other models. The average cost of misclassification, considering the consequences of false positives and false negatives, was determined to be 1682.4. This cost factor is a crucial metric for assessing the real-world financial impact of model predictions.
#
# 3. **Ensemble Methods:** Voting Classification, an ensemble method, also delivered competitive results with a balanced accuracy of 82.5% and an average cost of 1680.8. Ensemble methods leverage the strengths of multiple models to enhance overall predictive performance.
#
# 4. **Savings Potential:** The project showcased potential annual savings for insurance providers by implementing predictive models. The hypothetical scenario, based on model accuracy of 83%, indicated an annual savings of $10,020,000. This represents a substantial financial benefit achieved through more accurate identification of non-smokers.
#
# 5. **Business Implications:** The findings underscore the practical implications for insurance companies seeking to optimize premium calculations and risk management. By implementing advanced predictive analytics, businesses can achieve a delicate balance between accuracy and cost-effectiveness, leading to fairer premium adjustments.
#
# 6. **Decision-Making Insights:** The project provides valuable insights for decision-makers, emphasizing the importance of understanding the trade-offs between model accuracy, interpretability, and financial implications. Decision-makers can leverage these insights to make informed choices aligned with organizational goals and priorities.
#
# In conclusion, the project's quantitative analysis emphasizes the tangible benefits of leveraging predictive analytics in the insurance industry. XGBoost stands out as the top-performing model, striking a balance between accuracy and cost-effectiveness. The potential for substantial annual savings highlights the practical relevance of the project's outcomes for insurance providers.

# %% [markdown]
# ## Real World Analysis and Application

# %% [markdown]
# Consider a real-life scenario where an insurance company grapples with the task of precisely identifying smokers among policyholders for premium rate determinations. Currently lacking a predictive model, the company resorts to conventional premium calculations for both smokers and non-smokers.
#
# Using our model let us calculate the potential savings of the company.

# %% [markdown]
# Calculation:
#
# Premium Calculation Without Model (Current System):
# Total Annual Premium Income Without Model = (20,000 Smokers * $3,450) + (80,000 Non-Smokers * $2,300)
#  Premium Calculation with Model (Accuracy: 83%):
# Total Annual Premium Income with Model = (3,400 Misclassified Smokers * $2,300) + (66,400 Correctly Identified Non-Smokers * $2,300)
#  Potential Savings Calculation:
# Annual Savings = Total Premium Income Without Model - Total Premium Income with Model
#
#  Results:
# Total Annual Premium Income Without Model: $293,000,000
#
# Total Annual Premium Income with Model: $282,980,000
#
# Potential Annual Savings: $10,020,000
#
#  Interpretation:
# In this hypothetical scenario, the insurance company could potentially save $10,020,000 annually by implementing a model with an accuracy of 83% to identify non-smokers more accurately and apply regular premiums to them. This represents potential cost savings while maintaining fairness in premium pricing. Keep in mind that these numbers are based on assumptions and should be considered illustrative.
